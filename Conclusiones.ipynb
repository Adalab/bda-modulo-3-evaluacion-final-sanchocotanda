# %% [markdown]
# # CONCLUSIONES DEL ANALISIS
#
# **En cuanto al ejercicio**
#
# En la *primera fase* del analisis, limpieza y exploracion, he intentado seguir lo mejor posible lo visto en clase y aplicar buenas practicas. Me ha gustado esta parte: limpiarlo, pensar en que había que corregir, buscar los nulos, entender cual es la mejor forma de imputarlos, itnentar no eliminar ninguna columna y adaptarla por si es necesaria en el futuro. Incluso guardar los archivos limpios y crear uno unido, cosa que me ha parecido mucho más facil de lo que pensaba. No acababa de comrpender como se hacía hasta ahora.
#
# En esta fase me han surgido bastantes dudas, y no he sabido bien como gestionar la *primera fase* con la *segunda fase*, ya que lo entendia todo como una única fase en mi cabeza. Al limpiar los datos e imputar nulos, por ejemplo, me surgían preguntas y necesitaba hacer alguna comprobacion que not enía claro si debia de hacerse en la primera fase o en la segunda. Por eso creo que la segunda fase no está bien estructurada. No la he tenido biene structurada en la cabeza y creo que eso se nota en el código y la información buscada.
#
# En *tercera y cuarta fase* he comprobado lo dificl que es obtener resultados que realmente digan algo, encontrar algun dato que pueda demostrar una anomalia que pudiera tener relevancia real en la empresa de alguna manera.
# Y, aunque no me ha dado tiempo a hacerlo (lo haré más adelante) me hubiera gustado hacer estas comprobaciones:
#
# -  En que mes y año se dieron de alta más usuarios y cuantos eran hombres y mujeres.
# -  Que top 10 usuarios han cogido más vuelos y si tienen características en comun.
# -  Cuanta gente ha viajado compañada y cuantos eran hombres y mujeres
# -  Si los usuarios que cancelaron sus cuentas tenían puntos y, de tenerlos, si los habian canjeado antes de cerrarlas.
# -  Cuantos usuarios que cancelaron sus cuentas eran hombres y cuantos mujeres.
# -  Qque salarios, nivel de estudios y provincia tienen los usuarios que viajaron compañados.
#
# Es una lástima no haber podido contestar a estas preguntas, porque creo que pueden ser interesantes. Lo dejo apra el futuro.
#
#
#
# **En cuanto a la información obtenida**
#
# No veo ninguna información que sea relevante para un fin específico, o no he sabido encontrarla, por eso me gustaría seguir investigando.
# Los vuelos se concentran, tanto en 2017 como 2018, en picos de temporada alta, siendo los picos mas altos en los meses de verano, y en Navidad y año nuevo. Navidad y año nuevo menor que verano, estaría a la altura de abril y mayo.
#
# La relacion entre distancia de vuelo y puntos acumulados es directamente proporcional.
#
# La gran mayoria de usuarios se capton de manera standard y en conjunto, el procentaje de hombres y mujeres está al 50%.
# La mayoria de los clientes está en las ciudades más grandes, a mayor nivel educativo mayor salario. No ha habido prácticamente cancelaciones. Son todo datos muy coherentes.
#
# Es posible que no haya nada que llame demasiado la atención pero creo que, hecho este trabajo, merece la pena seguir investigando.
